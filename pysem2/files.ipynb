# %%
f = open("file.txt","rt")
f.readline()
print(f.readline())
f.close()
# Out:
# Hello world 2

# %%
f = open("write.txt","at")
f.write("it is a appended file")
f.close()
f = open("write.txt","rt")
print(f.read())
f.close()
# Out:
# it is a appended fileit is a appended file

# %%
f = open("a.txt","x")

# %%
import os
os.remove("write.txt")
